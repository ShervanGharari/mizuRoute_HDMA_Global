# %% [markdown]
# ## read the data and put the flow into a data frame

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot  as plt
import matplotlib
font = {'family' : 'Times New Roman',
            'weight' : 'bold',
            'size'   : 40}
matplotlib.rc('font', **font)
from easymore.easymore import easymore
import contextily as ctx

# %% [markdown]
# # Creating the point shapefile from the streamflow nc files, read the CSV of seg_id and populate lat lon

# %%
# read and match data to the 
# relating_df = pd.read_csv('../data/D09/D09_925.HDMA.big-rivers.asc')
relating_df = pd.read_csv('../data/D09/D09_925.HDMA.csv')
relating_df ['lat'] = None
relating_df ['lon'] = None

# add the lat/lon
# read the dataset
ds = xr.open_dataset('../data/D09/coastal-stns-Vol-monthly.updated-May2019.mod.nc', decode_times=False)

# 
df = pd.DataFrame()
df['lat'] = ds['lat'][:]
df['lon'] = ds['lon'][:]
df['id']  = ds['id'][:]

for index, row in relating_df.iterrows():
    gauge_id = row.gauge_id
    df_slice = df[df['id']==gauge_id]
    relating_df.lat.loc[index] = df_slice.lat.iloc[0]
    relating_df.lon.loc[index] = df_slice.lon.iloc[0]
    
relating_df

# initializing EASYMORE object
esmr = easymore()
shp_points = esmr.make_shape_point(relating_df,
                                   'lon',
                                   'lat')
shp_points.plot()


# name of target river 
target_rivers = ['Nelson','Mackenzie','St Lawrence','San Juan','Euphrates (Fira',\
                 'Parana','Yenisey','Changjiang','Nile']

relating_df = relating_df[relating_df['riv_name'].isin(target_rivers)]

print(relating_df)
# Out:
#      gauge_id  route_id  gauge_area  route_area  pct_area_bias  flag  \
# 0        7676   4033901     14005.0    14078.67           0.53     0
# 1        7721   4015213       225.0      653.26         190.34     1
# 2        7722   4010371       390.0      451.01          15.64     0
# 3        7724   4040303        18.0     2416.82       13326.80     1
# 4        7725   4009291       426.0      412.28          -3.22     0
# ..        ...       ...         ...         ...            ...   ...
# 917     96188   4040369       670.0      194.85         -70.92     1
# 918     96189   4005894      1050.0      339.05         -67.71     1
# 919     97062   4037503    463000.0   470381.19           1.59     0
# 920   1289200   2059495     25110.0    36022.20          43.46     1
# 921   3308300   5031699     14000.0    13274.80          -5.18     0
#
#         riv_name comment
# 0    Tana (Teno)     NaN
# 1         Bruara     NaN
# 2         Svarta     NaN
# 3      Kjerringa     NaN
# ...

# %%
# read the dataset
ds = xr.open_dataset('../data/D09/coastal-stns-Vol-monthly.updated-May2019.mod.nc', decode_times=False)

# FLOW
FLOW = np.array(ds['FLOW'][:])
COLUMNS = list(np.array(ds['id'][:]).astype(str))

# dataindex
dateindex = pd.date_range('1900-01','2018-12', freq= 'MS')+pd.DateOffset(days=14) # first year 190001, end 201812
dateindex = pd.date_range('1900-01','2018-12', freq= 'MS')+pd.DateOffset(days=0) # first year 190001, end 201812


observation = pd.DataFrame(FLOW[:,:],index = dateindex, columns = COLUMNS) # 

# 
observation_slice = observation[observation.columns.intersection(list(relating_df['gauge_id'].astype(str)))]
observation_slice = observation_slice.resample('D').ffill()
observation_slice
# Out:
#                   9306  90973  35021         9550  10224  9483  9143  9215  \
# 1900-01-01  9609.90918    NaN    NaN  6126.826660    NaN   NaN   NaN   NaN
# 1900-01-02  9609.90918    NaN    NaN  6126.826660    NaN   NaN   NaN   NaN
# 1900-01-03  9609.90918    NaN    NaN  6126.826660    NaN   NaN   NaN   NaN
# 1900-01-04  9609.90918    NaN    NaN  6126.826660    NaN   NaN   NaN   NaN
# 1900-01-05  9609.90918    NaN    NaN  6126.826660    NaN   NaN   NaN   NaN
# ...                ...    ...    ...          ...    ...   ...   ...   ...
# 2018-11-27         NaN    NaN    NaN  7971.192383    NaN   NaN   NaN   NaN
# 2018-11-28         NaN    NaN    NaN  7971.192383    NaN   NaN   NaN   NaN
# 2018-11-29         NaN    NaN    NaN  7971.192383    NaN   NaN   NaN   NaN
# 2018-11-30         NaN    NaN    NaN  7971.192383    NaN   NaN   NaN   NaN
# 2018-12-01         NaN    NaN    NaN  8268.519531    NaN   NaN   NaN   NaN
#
#             9705
# 1900-01-01   NaN
# 1900-01-02   NaN
# ...

# %%
# read mizuRoute output and make it to dataframe

simulation = xr.open_dataset('/Users/shg096/Desktop/cesm_coupling_no_lake.mizuroute.h.1999-01-01-00000.nc')
# a none leap year

print(simulation)

# FLOW
FLOW = np.array(simulation['IRFroutedRunoff'][:])
COLUMNS = list(np.array(simulation['reachID'][:]).astype(str))

# dataindex
dateindex = pd.date_range(str(simulation.time.values[0]),
                          str(simulation.time.values[-1]),
                          freq= 'D') #

print(len(dateindex))
simulation = pd.DataFrame(FLOW[:,:],index = dateindex, columns = COLUMNS) # 
simulation_slice_no_lake = simulation[simulation.columns.intersection(list(relating_df['route_id'].astype(str)))]
simulation_slice_no_lake
# Out:
# <xarray.Dataset>
# Dimensions:            (hru: 295554, seg: 295554, time: 365)
# Coordinates:
#   * time               (time) object 1999-01-01 00:00:00 ... 1999-12-31 00:00:00
# Dimensions without coordinates: hru, seg
# Data variables:
#     basinID            (hru) int32 ...
#     reachID            (seg) int32 ...
#     basRunoff          (time, hru) float32 ...
#     instRunoff         (time, seg) float32 ...
#     dlayRunoff         (time, seg) float32 ...
#     sumUpstreamRunoff  (time, seg) float32 ...
#     KWTroutedRunoff    (time, seg) float32 ...
#     IRFroutedRunoff    (time, seg) float32 ...
#     IRFlakeVol         (time, seg) float32 ...
# 365
#                  2063682     1073016       5036937      4037429      3041958  \
# 1999-01-01   6457.400391  588.870056  48128.277344   778.532166  1311.057739
# 1999-01-02   6344.089844  583.222961  48388.507812   844.769836  1356.393433
# 1999-01-03   6271.087402  577.722595  48141.476562   956.737366  1398.428833
# ...

# %%
# read mizuRoute output and make it to dataframe

simulation = xr.open_dataset('/Users/shg096/Desktop/hybrid_test.mizuroute.h.1999-01-01-00000.nc')
# a none leap year

print(simulation)

# FLOW
FLOW = np.array(simulation['IRFroutedRunoff'][:])
COLUMNS = list(np.array(simulation['reachID'][:]).astype(str))

# dataindex
dateindex = pd.date_range(str(simulation.time.values[0]),
                          str(simulation.time.values[-1]),
                          freq= 'D') #

print(len(dateindex))
simulation = pd.DataFrame(FLOW[:,:],index = dateindex, columns = COLUMNS) # 
simulation_slice_lake = simulation[simulation.columns.intersection(list(relating_df['route_id'].astype(str)))]
simulation_slice_lake
# Out:
# <xarray.Dataset>
# Dimensions:            (hru: 295554, seg: 295554, time: 365)
# Coordinates:
#   * time               (time) object 1999-01-01 00:00:00 ... 1999-12-31 00:00:00
# Dimensions without coordinates: hru, seg
# Data variables:
#     basinID            (hru) int32 ...
#     reachID            (seg) int32 ...
#     basRunoff          (time, hru) float32 ...
#     instRunoff         (time, seg) float32 ...
#     dlayRunoff         (time, seg) float32 ...
#     sumUpstreamRunoff  (time, seg) float32 ...
#     KWTroutedRunoff    (time, seg) float32 ...
#     IRFroutedRunoff    (time, seg) float32 ...
#     IRFlakeVol         (time, seg) float32 ...
# 365
#                  2063682      1073016       5036937      4037429      3041958  \
# 1999-01-01  14987.804688  3031.372314  36250.230469  1014.946350  1205.157959
# 1999-01-02  14800.817383  3018.719727  36625.812500  1014.993103  1216.105957
# 1999-01-03  14615.700195  3006.145508  36694.246094  1015.981323  1241.048706
# ...

# %%
# draw the comparison

for index, row in relating_df.iterrows():
    
    # get the obseration gauge_id

    
    if (str(row.gauge_id) in list(observation_slice.columns)) and \
    (str(row.route_id) in list(simulation_slice_no_lake.columns)) and \
    (str(row.route_id) in list(simulation_slice_lake.columns)):
        
        plt.figure(index, figsize=(20, 10))
            
        observation_slice[str(row.gauge_id)].plot(c='DarkBlue')
        simulation_slice_no_lake[str(row.route_id)].plot(c='red')
        simulation_slice_lake[str(row.route_id)].plot(c='green')

        plt.xlim(pd.Timestamp('1999-01-01'), pd.Timestamp('2000-01-01'))
        plt.xlim(pd.Timestamp('1990-01-01'), pd.Timestamp('2000-01-01'))
        plt.title(row.riv_name+' lat: '+str(row.lat)+' lon: '+str(row.lon))

        plt.grid()

# %% [markdown]
# ## caclulate NS values

# %%
# definision fo NS values

def NS(s,o):
    """
    Created on Thu Jan 20 15:36:37 2011
    @ author:                  Sat Kumar Tomer
    @ author's webpage:        http://civil.iisc.ernet.in/~satkumar/
    @ author's email id:       satkumartomer@gmail.com
    @ author's website:        www.ambhas.com
    Nash Sutcliffe efficiency coefficient
    input:
        s: simulated [time]
        o: observed [time]
    output:
        ns: Nash Sutcliffe efficient coefficient
    """
    s,o = filter_nan(s,o)
    return 1 - sum((s-o)**2)/sum((o-np.mean(o))**2)


def filter_nan(s,o):
    """
    Created on Thu Jan 20 15:36:37 2011
    @ author:                  Sat Kumar Tomer
    @ author's webpage:        http://civil.iisc.ernet.in/~satkumar/
    @ author's email id:       satkumartomer@gmail.com
    @ author's website:        www.ambhas.com
    this functions removed the data  from simulated and observed data
    whereever the observed data contains nan
    this is used by all other functions, otherwise they will produce nan as
    output
    """
    data = np.array([s.flatten(),o.flatten()])
    data = np.transpose(data)
    data = data[~np.isnan(data).any(1)]
    return data[:,0],data[:,1]



# read mizuRoute output and make it to dataframe
simulation = xr.open_dataset('/Users/shg096/Desktop/cesm_coupling_no_lake.mizuroute.h.1999-01-01-00000.nc')
# a none leap year
print(simulation)
# FLOW
FLOW = np.array(simulation['IRFroutedRunoff'][:])
COLUMNS = list(np.array(simulation['reachID'][:]).astype(str))
# dataindex
dateindex = pd.date_range(str(simulation.time.values[0]),
                          str(simulation.time.values[-1]),
                          freq= 'D') #
print(len(dateindex))
simulation = pd.DataFrame(FLOW[:,:],index = dateindex, columns = COLUMNS) # 
simulation_no_lake = simulation



# read mizuRoute output and make it to dataframe
simulation = xr.open_dataset('/Users/shg096/Desktop/hybrid_test.mizuroute.h.1999-01-01-00000.nc')
# a none leap year
print(simulation)
# FLOW
FLOW = np.array(simulation['IRFroutedRunoff'][:])
COLUMNS = list(np.array(simulation['reachID'][:]).astype(str))
# dataindex
dateindex = pd.date_range(str(simulation.time.values[0]),
                          str(simulation.time.values[-1]),
                          freq= 'D') #
print(len(dateindex))
simulation = pd.DataFrame(FLOW[:,:],index = dateindex, columns = COLUMNS) # 
simulation_lake = simulation

# loop over the segment and calculate the values of NSE
shp = gpd.read_file('/Volumes/F:/hydrography/HDMA/processed/hdma_global_stream.shp')
shp ['obj'] = -9999
# shp = shp.drop(columns='geometry')
for index, row in shp.iterrows():
    print(index)
    if str(row['seg_id']) in COLUMNS:
        obs_seg = np.array(simulation_lake    [str(row['seg_id'])])
        sim_seg = np.array(simulation_no_lake [str(row['seg_id'])])
        shp ['obj'].loc[index] = 1-NS(sim_seg,obs_seg)
# Out:
# <xarray.Dataset>
# Dimensions:            (time: 365, hru: 295554, seg: 295554)
# Coordinates:
#   * time               (time) object 1999-01-01 00:00:00 ... 1999-12-31 00:00:00
# Dimensions without coordinates: hru, seg
# Data variables:
#     basinID            (hru) int32 ...
#     reachID            (seg) int32 ...
#     basRunoff          (time, hru) float32 ...
#     instRunoff         (time, seg) float32 ...
#     dlayRunoff         (time, seg) float32 ...
#     sumUpstreamRunoff  (time, seg) float32 ...
#     KWTroutedRunoff    (time, seg) float32 ...
#     IRFroutedRunoff    (time, seg) float32 ...
#     IRFlakeVol         (time, seg) float32 ...
# 365
# <xarray.Dataset>
# Dimensions:            (time: 365, hru: 295554, seg: 295554)
# Coordinates:
#   * time               (time) object 1999-01-01 00:00:00 ... 1999-12-31 00:00:00
# Dimensions without coordinates: hru, seg
# Data variables:
#     basinID            (hru) int32 ...
#     reachID            (seg) int32 ...
# ...

# %%
simulation = xr.open_dataset('/Users/shg096/Desktop/cesm_coupling_no_lake.mizuroute.h.1999-01-01-00000.nc')

A = np.array(simulation['reachID'][:])

idx = np.where(A>7000000)

A = A[idx]

print(A)

# lakes = gpd.read_file('/Volumes/F:/hydrography/hydrolakes/HydroLAKES_polys_v10_shp/HydroLAKES_polys_v10_shp/HydroLAKES_polys_v10.shp')
lakes = lakes[lakes['Hylak_id'].isin(A)]
# Out:
# [1707  888  892 ... 1576 1574 1572]

# %%
#plotting
fig, ax = plt.subplots(figsize=(40,20))

ax.set_facecolor('white')
fig.patch.set_facecolor('white')

shp_slice = shp [shp['obj']>0.01]

# shp_slice = shp_slice.to_crs(epsg=3857) # trasnforation for the basemap

A = shp_slice.plot (ax=ax, column='obj',
                    cmap='Oranges',
                    vmin=0 , vmax=0.5 , linewidth=2,
                    norm=plt.Normalize(vmin=0, vmax=0.5),
                    zorder=10)#, legend = True)


#lakes_buffer = lakes.simplify(0.1)
lakes_buffer = lakes.buffer(0.1)
#lakes_buffer = lakes.simplify(0.1)
lakes_buffer.plot(ax = ax, zorder=10, color= 'blue', linewidth=3)

# pos   = ax.get_position()
# cb_ax = fig.add_axes([pos.x1+0.03, pos.y0, 0.02, (pos.y1-pos.y0)])
# cbar  = fig.colorbar(A, cax=cb_ax)

# add title and save
plt.title('Impact of Lakes and Reservoirs on Streamflow Globally')
plt.xlabel('Easting [m]') #xlable which is long
plt.ylabel('Northing/Southing [m]') #ylable which is lat


# add basemap
ctx.add_basemap(ax,
                crs=shp_slice.crs,
                zoom=3,
                alpha = 0.4,
                source=ctx.providers.Stamen.TonerLite) # source=ctx.providers.Stamen.TonerLite

plt.tight_layout()

plt.savefig('../frame/HDMA_HydroLake.png', dpi=400)
# Out:
# /var/folders/yh/b1qy7zb96k980mcb2ps9n6d9t1c6zr/T/ipykernel_68535/531111903.py:19: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   lakes_buffer = lakes_buffer.buffer(0.1)
